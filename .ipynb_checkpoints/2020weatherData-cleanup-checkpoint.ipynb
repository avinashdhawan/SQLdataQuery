# %%
import pandas as pd

# %%
# Store filepath in a variable
weather2020 = "2020WeatherDataTCC.csv"

# %%
# Read our Data file with the pandas library

weather2020_df = pd.read_csv(weather2020)
weather2020_df
# Out:
#      Longitude (x)  Latitude (y)         Station Name  Climate ID   Date/Time  \
# 0            -79.4         43.63  TORONTO CITY CENTRE     6158359  2020-01-01
# 1            -79.4         43.63  TORONTO CITY CENTRE     6158359  2020-01-02
# 2            -79.4         43.63  TORONTO CITY CENTRE     6158359  2020-01-03
# 3            -79.4         43.63  TORONTO CITY CENTRE     6158359  2020-01-04
# 4            -79.4         43.63  TORONTO CITY CENTRE     6158359  2020-01-05
# ..             ...           ...                  ...         ...         ...
# 361          -79.4         43.63  TORONTO CITY CENTRE     6158359  2020-12-27
# 362          -79.4         43.63  TORONTO CITY CENTRE     6158359  2020-12-28
# 363          -79.4         43.63  TORONTO CITY CENTRE     6158359  2020-12-29
# 364          -79.4         43.63  TORONTO CITY CENTRE     6158359  2020-12-30
# 365          -79.4         43.63  TORONTO CITY CENTRE     6158359  2020-12-31
#
# ...

# %%
weather2020_df=weather2020_df.drop(["Climate ID","Data Quality","Max Temp Flag","Min Temp Flag","Mean Temp Flag","Heat Deg Days Flag","Cool Deg Days Flag","Total Rain Flag","Total Snow Flag","Total Precip Flag","Snow on Grnd Flag","Dir of Max Gust Flag","Spd of Max Gust Flag"
], axis=1)
weather2020_df
# Out:
#      Longitude (x)  Latitude (y)         Station Name   Date/Time  Year  \
# 0            -79.4         43.63  TORONTO CITY CENTRE  2020-01-01  2020
# 1            -79.4         43.63  TORONTO CITY CENTRE  2020-01-02  2020
# 2            -79.4         43.63  TORONTO CITY CENTRE  2020-01-03  2020
# 3            -79.4         43.63  TORONTO CITY CENTRE  2020-01-04  2020
# 4            -79.4         43.63  TORONTO CITY CENTRE  2020-01-05  2020
# ..             ...           ...                  ...         ...   ...
# 361          -79.4         43.63  TORONTO CITY CENTRE  2020-12-27  2020
# 362          -79.4         43.63  TORONTO CITY CENTRE  2020-12-28  2020
# 363          -79.4         43.63  TORONTO CITY CENTRE  2020-12-29  2020
# 364          -79.4         43.63  TORONTO CITY CENTRE  2020-12-30  2020
# 365          -79.4         43.63  TORONTO CITY CENTRE  2020-12-31  2020
#
#      Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# ...

# %%
weather2020_df.fillna("",inplace = True)
weather2020_df
# Out:
#      Longitude (x)  Latitude (y)         Station Name   Date/Time  Year  \
# 0            -79.4         43.63  TORONTO CITY CENTRE  2020-01-01  2020
# 1            -79.4         43.63  TORONTO CITY CENTRE  2020-01-02  2020
# 2            -79.4         43.63  TORONTO CITY CENTRE  2020-01-03  2020
# 3            -79.4         43.63  TORONTO CITY CENTRE  2020-01-04  2020
# 4            -79.4         43.63  TORONTO CITY CENTRE  2020-01-05  2020
# ..             ...           ...                  ...         ...   ...
# 361          -79.4         43.63  TORONTO CITY CENTRE  2020-12-27  2020
# 362          -79.4         43.63  TORONTO CITY CENTRE  2020-12-28  2020
# 363          -79.4         43.63  TORONTO CITY CENTRE  2020-12-29  2020
# 364          -79.4         43.63  TORONTO CITY CENTRE  2020-12-30  2020
# 365          -79.4         43.63  TORONTO CITY CENTRE  2020-12-31  2020
#
#      Month  Day Max Temp (°C) Min Temp (°C) Mean Temp (°C) Heat Deg Days (°C)  \
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header if inde
weather2020_df.to_csv("weather2020.csv", index=False, header=True)
