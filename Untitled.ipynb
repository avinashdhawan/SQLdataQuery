# %%
import pandas as pd

# %%
# Store filepath in a variable
weather2019 = "2019WeatherDataTCC.csv"

# %%
# Read our Data file with the pandas library

weather2019_df = pd.read_csv(weather2019)
weather2019_df
# Out:
#      Longitude (x)  Latitude (y)         Station Name  Climate ID        Date  \
# 0            -79.4         43.63  TORONTO CITY CENTRE     6158359  2019-01-01
# 1            -79.4         43.63  TORONTO CITY CENTRE     6158359  2019-01-02
# 2            -79.4         43.63  TORONTO CITY CENTRE     6158359  2019-01-03
# 3            -79.4         43.63  TORONTO CITY CENTRE     6158359  2019-01-04
# 4            -79.4         43.63  TORONTO CITY CENTRE     6158359  2019-01-05
# ..             ...           ...                  ...         ...         ...
# 360          -79.4         43.63  TORONTO CITY CENTRE     6158359  2019-12-27
# 361          -79.4         43.63  TORONTO CITY CENTRE     6158359  2019-12-28
# 362          -79.4         43.63  TORONTO CITY CENTRE     6158359  2019-12-29
# 363          -79.4         43.63  TORONTO CITY CENTRE     6158359  2019-12-30
# 364          -79.4         43.63  TORONTO CITY CENTRE     6158359  2019-12-31
#
#      Year  Month  Day  Data Quality  Max Temp (°C)  ... Total Snow (cm)  \
# 0    2019      1    1           NaN            6.1  ...             NaN
# 1    2019      1    2           NaN            0.4  ...             NaN
# 2    2019      1    3           NaN            1.8  ...             NaN
# 3    2019      1    4           NaN            6.6  ...             NaN
# 4    2019      1    5           NaN            3.6  ...             NaN
# ..    ...    ...  ...           ...            ...  ...             ...
# 360  2019     12   27           NaN           11.2  ...             NaN
# 361  2019     12   28           NaN            3.8  ...             NaN
# 362  2019     12   29           NaN            2.6  ...             NaN
# 363  2019     12   30           NaN            7.7  ...             NaN
# 364  2019     12   31           NaN            3.2  ...             NaN
#
#      Total Snow Flag Total Precip (mm)  Total Precip Flag Snow on Grnd (cm)  \
# 0                NaN               0.4                NaN               NaN
# 1                NaN               2.1                NaN               NaN
# 2                NaN               0.0                NaN               NaN
# 3                NaN               0.0                NaN               NaN
# 4                NaN               0.0                NaN               NaN
# ..               ...               ...                ...               ...
# 360              NaN               0.0                NaN               NaN
# 361              NaN               0.0                NaN               NaN
# 362              NaN               7.7                NaN               NaN
# 363              NaN              11.6                NaN               NaN
# 364              NaN               0.4                NaN               NaN
#
#      Snow on Grnd Flag Dir of Max Gust (10s deg)  Dir of Max Gust Flag  \
# 0                  NaN                      29.0                   NaN
# 1                  NaN                       NaN                     M
# 2                  NaN                      24.0                   NaN
# 3                  NaN                      24.0                   NaN
# 4                  NaN                      23.0                   NaN
# ..                 ...                       ...                   ...
# 360                NaN                      28.0                   NaN
# 361                NaN                      31.0                   NaN
# 362                NaN                       6.0                   NaN
# 363                NaN                       7.0                   NaN
# 364                NaN                      23.0                   NaN
#
#     Spd of Max Gust (km/h)  Spd of Max Gust Flag
# 0                     55.0                   NaN
# 1                      NaN                     M
# 2                     48.0                   NaN
# 3                     41.0                   NaN
# 4                     39.0                   NaN
# ..                     ...                   ...
# 360                   50.0                   NaN
# 361                   32.0                   NaN
# 362                   65.0                   NaN
# 363                   81.0                   NaN
# 364                   55.0                   NaN
#
# [365 rows x 31 columns]

# %%
weather2019_df=weather2019_df.drop(["Climate ID","Data Quality","Max Temp Flag","Min Temp Flag","Mean Temp Flag","Heat Deg Days Flag","Cool Deg Days Flag","Total Rain Flag","Total Snow Flag","Total Precip Flag","Snow on Grnd Flag","Dir of Max Gust Flag","Spd of Max Gust Flag"
], axis=1)
weather2019_df
# Out:
#      Longitude (x)  Latitude (y)         Station Name        Date  Year  \
# 0            -79.4         43.63  TORONTO CITY CENTRE  2019-01-01  2019
# 1            -79.4         43.63  TORONTO CITY CENTRE  2019-01-02  2019
# 2            -79.4         43.63  TORONTO CITY CENTRE  2019-01-03  2019
# 3            -79.4         43.63  TORONTO CITY CENTRE  2019-01-04  2019
# 4            -79.4         43.63  TORONTO CITY CENTRE  2019-01-05  2019
# ..             ...           ...                  ...         ...   ...
# 360          -79.4         43.63  TORONTO CITY CENTRE  2019-12-27  2019
# 361          -79.4         43.63  TORONTO CITY CENTRE  2019-12-28  2019
# 362          -79.4         43.63  TORONTO CITY CENTRE  2019-12-29  2019
# 363          -79.4         43.63  TORONTO CITY CENTRE  2019-12-30  2019
# 364          -79.4         43.63  TORONTO CITY CENTRE  2019-12-31  2019
#
#      Month  Day  Max Temp (°C)  Min Temp (°C)  Mean Temp (°C)  \
# 0        1    1            6.1           -6.7            -0.3
# 1        1    2            0.4           -7.9            -3.8
# 2        1    3            1.8           -0.4             0.7
# 3        1    4            6.6            1.5             4.1
# 4        1    5            3.6            1.2             2.4
# ..     ...  ...            ...            ...             ...
# 360     12   27           11.2            3.2             7.2
# 361     12   28            3.8            1.7             2.8
# 362     12   29            2.6            1.1             1.9
# 363     12   30            7.7            1.7             4.7
# 364     12   31            3.2           -0.2             1.5
#
#      Heat Deg Days (°C)  Cool Deg Days (°C)  Total Rain (mm)  Total Snow (cm)  \
# 0                  18.3                 0.0              NaN              NaN
# 1                  21.8                 0.0              NaN              NaN
# 2                  17.3                 0.0              NaN              NaN
# 3                  13.9                 0.0              NaN              NaN
# 4                  15.6                 0.0              NaN              NaN
# ..                  ...                 ...              ...              ...
# 360                10.8                 0.0              NaN              NaN
# 361                15.2                 0.0              NaN              NaN
# 362                16.1                 0.0              NaN              NaN
# 363                13.3                 0.0              NaN              NaN
# 364                16.5                 0.0              NaN              NaN
#
#      Total Precip (mm)  Snow on Grnd (cm)  Dir of Max Gust (10s deg)  \
# 0                  0.4                NaN                       29.0
# 1                  2.1                NaN                        NaN
# 2                  0.0                NaN                       24.0
# 3                  0.0                NaN                       24.0
# 4                  0.0                NaN                       23.0
# ..                 ...                ...                        ...
# 360                0.0                NaN                       28.0
# 361                0.0                NaN                       31.0
# 362                7.7                NaN                        6.0
# 363               11.6                NaN                        7.0
# 364                0.4                NaN                       23.0
#
#      Spd of Max Gust (km/h)
# 0                      55.0
# 1                       NaN
# 2                      48.0
# 3                      41.0
# 4                      39.0
# ..                      ...
# 360                    50.0
# 361                    32.0
# 362                    65.0
# 363                    81.0
# 364                    55.0
#
# [365 rows x 18 columns]

# %%
weather2019_df.fillna("",inplace = True)
weather2019_df
